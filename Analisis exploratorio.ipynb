# %%
# importa las librerías a nuestro entorno de trabajo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diamonds.csv", sep=",")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3d43b4af3617> in <cell line: 1>()
# ----> 1 df = pd.read_csv("diamonds.csv", sep=",")
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(x = df['cut'], bins = 10)
plt.xlabel("El corte de los diamantes")
plt.ylabel("Cantidad de diamantes")
plt.title("Cantidad de diamantes segun su corte")
plt.show()

# %% [markdown]
# ### La mayor cantidad de diamantes es con corte ideal y la menor cantidad de diamantes tienen un corte regular.

# %%
plt.figure(figsize=(5,5))
corr = df.corr(method ='pearson');
plt.figure(figsize=(10,10))  # tamaño del gráfico
sns.heatmap(data=corr,square=True, annot=True,cmap='coolwarm');

# %%
#Gráfico 3 torta
df['color'].value_counts().plot.pie(figsize=(5,5), autopct="%0.1f %%");

# %%
plt.figure(figsize=(15,2))
sns.boxplot(x=df['price'], fliersize=5, width=0.5);

# %% [markdown]
# hgfdhgfgfdhjhgfdjhgfd

# %%
plt.figure(figsize=(5,5))
plt.hist(x = df['depth'], bins = 10)
plt.xlabel("Altura en mm")
plt.ylabel("Cantidad de diamantes")
plt.title("La altura de los diamantes")
plt.show()

# %%
#Tablas pivote
precioCorte= df[['color','price']].groupby('color')
precioCorte.agg("sum")
# Out:
#           price
# color
# D      21476439
# E      30142944
# F      35542866
# G      45158240
# H      37257301
# I      27608146
# J      14949281

# %%
plt.figure(figsize=(5,5))
plt.hist(x = df['clarity'], bins = 10)
plt.xlabel("Categoria de diamantes")
plt.ylabel("Cantidad de diamantes")
plt.title("La cantidad de diamantes por su claridad")
plt.show()
